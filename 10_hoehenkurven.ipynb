# %% [markdown]
# ### Höhenkurven

# %%
import math
import seaborn as sns

# %%
#Ausgangsgleichung
def V(T_0, p):
    R = 8.31446261815324
    result = R * T_0 / p
    return result

#Intervalle für T und p
T_values = [10, 50, 100, 200, 300]
p_values = range(1, 101)
T_values_result = {}

#Ergebnisse von V(T,p) in ein Dictionary speichern
for T_value in T_values:
    current_result = []
    for p_value in p_values:
        current_result.append(V(T_value, p_value))
    T_values_result[T_value] = current_result

# %%
T_values_result
# Out:
# {10: [83.1446261815324,
#   41.5723130907662,
#   27.714875393844135,
#   20.7861565453831,
#   16.62892523630648,
#   13.857437696922068,
#   11.877803740218914,
#   10.39307827269155,
#   9.238291797948044,
#   8.31446261815324,
#   7.558602380139309,
#   6.928718848461034,
#   6.3957404755024925,
#   5.938901870109457,
#   5.542975078768827,
#   5.196539136345775,
#   4.890860363619553,
#   4.619145898974022,
#   4.376032956922758,
#   4.15723130907662,
#   3.959267913406305,
#   3.7793011900696545,
#   3.614983747023148,
#   3.464359424230517,
#   3.325785047261296,
#   3.1978702377512462,
#   3.079430599316015,
#   2.9694509350547285,
#   2.867056075225255,
#   2.7714875393844136,
#   2.6820847155333034,
#   2.5982695681728876,
#   2.5195341267131033,
#   2.4454301818097766,
#   2.375560748043783,
#   2.309572949487011,
#   2.247152058960335,
#   2.188016478461379,
#   2.131913491834164,
#   2.07861565453831,
#   2.027917711744693,
#   1.9796339567031525,
# ...
